# %% [markdown]
# # Extração de informações relevantes dos Extratos das Sessões de Julgamento dos PAS da CVM entre 2000 e 2023.
#
# ## Objetivo do código
# O objetivo do código em questão é extrair, dentro do possível, permitido computacionalmente, informações sobre as decisões dos PAS da CVM, entre 2000 e 2023.
#
# Os documentos usados foram os Extratos das Sessões de Julgamento dos PAS, disponíveis para download no site oficial da CVM. Os Extratos das Sessões de Julgamento são os documentos publicados na sessão de julgamento, que acontece após a apresentação de defesa por parte dos acusados. Neles, ficam registrados os votos de cada um dos diretores presentes, além de outras informações relevantes. Para mais informações, consultar o codebook disponível no Github (https://github.com/tomasrribeiro/corporate-fraud-in-brazil).
#
# O objetivo é colher 5 informações para cada documento. São elas:
# 1. Identificador do processo (*ID*): cada processo tem a ele um código associado. É importantíssimo que tenhamos esse código registrado para poder indexar quando necessário. O número do processo é colhido usando hífens no lugar de barras e pontos, para facilitar a indexação. Exemplo para um processo aleatório: "19957-004381-2021-68".
# 2. Data do julgamento (*Data*): a data em que a Sessão de Julgmento ocorre. Todo processo têm registrado em algum lugar a data de ocorrência. Ela pode estar em alguns formatos --- separada por barras ou por extenso. Exemplos: "12/12/2004" e "12 de dezembro de 2004"
# 3. Lista de acusados (*Acusados*): cada processo têm a ele associado uma lista de acusados, que pode conter um ou mais nomes, sendo eles pessoas físicas ou jurídicas. O objetivo é colher, para cada documento, a lista de acusado associada. Armazenamos a inforação no formato de uma lista dentro da base de dados. Exemplo colhido de um processo: "[Letícia Ferreira Duarte do Valle, Le Valle Agente Autônomo de Investimentos S/S Ltda.]".
# 4. Assunto ou ementa (*Assunto*): no cabeçalho de cada processo, temos uma breve descrição dos fatos. Normalmente, tem de 1 a 4 parágrafos e é importante pois dá uma visão geral do que está sendo julgado no processo. Exemplo de um processo: "Emissão de Parecer sem Abstenção de Opinião, em descumprimento ao item 21 da NBC T11-IT5, aprovada pela Resolução CFC Nº 830/98, que, por seu turno, representa uma infração ao art. 20 da Instrução CVM nº 308/99. Multas."
# 5. Decisão (*Decisão*): no cabeçalho, normalmente depois do assunto, temos uma breve descrição da decisão do Colegiado na Sessão de Julgamento. Exemplo, estraído de um processo: "Vistos, relatados e discutidos os autos, o Colegiado da Comissão de Valores Mobiliários, com base na prova dos autos e na legislação aplicável, por maioria de votos, decidiu aplicar aos acusados BC Control Auditores Independentes S/S e Sandro Casagrande a penalidade de multa pecuniária individual no valor de R$ 75.000,00, pelo descumprimento do item 21 da NBC T11-IT 5, que representa infração ao art. 20 da Instrução CVM nº 308/99."
#
# ## Método
# Usamos o pacote *pdfplumber* para colher as informações. Além disso, usamos expressões regulares para delimitar cada um dos tópicos do documento. Essas serão exploradas mais a fundo.
#
# A análise foi feita com base no texto das duas primeiras páginas. Apesar desse limite não ser oficial, para todos os processo que observamos, o "cabeçalho" (parte que contém essas 5 informações ou a maioria delas) estava contido nesse limite.
#
# O código foi construído com base em uma amostra escolhida aleatoriamente (n = 20, seed = 42) dentre os processos. A partir dessa amostra e da análise dos documentos nela presentes, as expressões regulares e a ordem e os métodos de colheita de informações foram adaptados, de forma a ter a maior eficiência possível, dentro da amostra. Se ela for represnetativa (acreditamos que, atéc erto ponto, depois de inúmeras leituras "na diagonal", ela seja), esperamos conseguir resultados semelhantes ao generalizar o código para todos os arquivos entre 2000 e 2023. Esse código também está disponível no Github.
#
# Agora, vamos analisar os critérios utilizados, por variável:
#
# ### *ID*:
# Para coletar o ID dos processos, usamos o nome (do arquivo) de cada um dos pdfs. Ao baixar a pasta com os arquivos dos Extratos das Sessões de Julgamento, notamos que os nomes estavam muito bem padronizados, para cada um dos documentos. Portanto, o que o código faz, para cada um dos documentos, é coletar o nome do arquivo e adicioná-lo à coluna de *ID*.
#
# Na amostra aleatória que colhemos, tivemos 100% dos identificadores de processo colhidos, dos quais 100% estavam corretos.
#
# ### *Data*:
# Para colher as datas do julgamento, usamos expressões regulares que foram construídas com base na observação da amostra.
#
# Para processos mais recentes, é fácil notar que normalmente, as primeiras páginas se iniciam com a expressão "Data do julgamento: XX/XX/20XX". Para todos os processos que tinham essa expressão regular, extraímos exatamente essa expressão.
#
# Já para os processos mais antigos, normalmente a parte preliminar dos documentos termina com a data, por extenso, da seguinte forma: "Rio de Janiero, XX de mês (janeiro, fevereiro, etc.) de 20XX." Usamos essa expressão regular, quando contida nas duas primeira páginas, para extrair a data da Sessão de Julgamento daquele PAS.
#
# Sobre a eficácia: para a amostra de 20 aruquivos, colhemos a data em 18 (90%) e ela estava correta em todas as ocasiões em que foi colhida. Para os outros dois arquivos, não conseguimos colher a data por que ela não estava disponível nas duas primeiras páginas do documento (o documento estava desconfigurado). Em um dos documentos, por exemplo, a data estava na página 10. Isso exigiria uma capacidade computacional e um tempo de processamento que é desnecessariamente grande (é melhor extrair as informações faltantes manualmente).
#
# ### *Acusados*:
# Novamente, usamos expressões regulares com base na observação da amostra. Na maior parte dos arquivos, notamos que a lista de acusados vem no formato "Acusados/Interessados/Indiciados: XXXX", seguida do assunto/ementa. Configuramos as expressões regulares com base nisso.
#
# Sobre a eficácia: para a amostra de 20 arquivos, coletamos a lista de acusados em 20 (100%) e ela estava correta para 19 dos 20 arquivos (95%). Até mesmo os arquivos desfigurados, mencionados na sessão anterior, tinham uma lista de acusados nas primeiras páginas. Por isso, imaginando uma amostra representativa, esperamos ter boa acurácia nesse tópico.
#
# A lista de acusados colhida de maneira errônea foi graças a uma vírgula no meio do nome de uma empresa, de forma qu o seu nome ("New Way Técnicas Administrativas, Assessoria e Planejamento Ltda."), ficasse separado em duas strings, pela vírgula. Acreditamos que a probabilidade de ocorrência desse tipo de erro seja baixa para a maior parte dos processos, mas é um tópico de atenção.
#
# ### *Assunto*:
# Para captar o assunto dos processos, usamos expressões regulares. Notamos que normalmente, o assunto segue um formato padrão: "Assunto/Ementa: XXX", eestá seguido da palavra "Decisão".
#
# Para o teste com a amostra de 20 arquivos, captamos o assunto de 18 (90%), dentre os quais 18 estavam corretos (100%). Os arquivos com os quais tivemos problemas foram os mesmos da seção de datas, graças à desfiguração. Ela vai ser discutida na seção posterior.
#
# ### *Decisão*:
# Normalmente, a decisão é introduzida sempre pela frase "Vistos, relatados e discutidos os autos". Usamos essa expressão regular para iniciar a captura. Ela estava presente em todas as decisões que captamos.
#
# Além disso, normalmente termina com uma expressão específica. Normalmente, depois de relatar a decisão, o relator dá o prazo para apresentação de recursos (30 dias, em todos os arquivos que obervamos). Por isso, usamos a expressão "30 dias" e suas variações como uma das "stopwords". Outra expressão muito usada é a data da sessão de julgamento, no formato por extenso. Usamos ela também. Além disso, em alguns casos, especialmente nos documentos mais recentes que analisamos, temos a expressão "Participaram desta Sessão", ou o fim da segunda página, como o fim da parte inicial dos autos.
#
# Para o teste com a amostra de 20 arquivos, captamos a decisão em 18 (90%), dentre as quais todas continham as partes que julgamos relevantes (100%). Novamente, o problema foi na captação da decisão dos mesmos dois arquivos desfigurados. Apesar disso, houve, em muitos casos, a captura de mais texto do que necessário (uma frase, ou alguns parágrafos a mais). Isso é um ponto de atenção, mas em todos os casos a decisão foi captada por completo (acreditamos que o limite de duas p´ginas na análise dos documentos foi importante nesse sentido.
#
# ## Possíveis perdas de dados (desconfiguração, documentos escaneados, etc.)
# Como comentado na seção anterior, observamos, para dois documentos, problemas na colheita dos dados. Em ambos os casos, os documentos não tinham a primeira página na estrutura que esperávamos (Acusados, Assunto, Decisão). Muito pelo contrário. O que aconteceu foi que não conseguimos colher esses dados por que eles não existiam dentro dos arquivos. Apesar disso, os dados disponíveis foram completamente colhidos. Isso, acreditamos é um indicativo de sucesso na acurária do código (nenhuma informação falsa/incorreta colhida, nenhum "falso positivo").
#
# No entanto, é importante saber, obviamente, que o código em questão não será capaz de colher a totalidade das informações dentro da pasta de mais de 900 arquivos baixados do site da CVM, mas acreditamos que boa parte estará lá.
#
# Outros problema que certamente vamos enfrentar: uma pequena parte (só nos deparamos com um até o momento) dos processos são imagens escaneadas dos autos dos processos. Nesse caso, o código não vai funcionar e as informações terão de ser registradas manualmente.

# %% [markdown]
# # Extração de informações relevantes dos Extratos das Sessões de Julgamento dos PAS da CVM entre 2000 e 2023.
#
# ## Objetivo do código
# O objetivo do código em questão é extrair, dentro do possível permitido computacionalmente, informações sobre as decisões dos PAS da CVM, entre 2000 e 2023.
#
# Os documentos usados foram os Extratos das Sessões de Julgamento dos PAS, disponíveis para download no site oficial da CVM. Os Extratos das Sessões de Julgamento são os documentos publicados na sessão de julgamento, que acontece após a apresentação de defesa por parte dos acusados. Neles, ficam registrados os votos de cada um dos diretores presentes, além de outras informações relevantes. Para mais informações, consultar o codebook disponível no Github (https://github.com/tomasrribeiro/corporate-fraud-in-brazil).
#
# O objetivo é colher 5 informações para cada documento. São elas:
# 1. Identificador do processo (*ID*): cada processo tem a ele um código associado. É importantíssimo que tenhamos esse código registrado para poder indexar quando necessário. O número do processo é colhido usando hífens no lugar de barras e pontos, para facilitar a indexação. Exemplo para um processo aleatório: "19957-004381-2021-68".
# 2. Data do julgamento (*Data*): a data em que a Sessão de Julgamento ocorre. Todo processo tem registrado em algum lugar a data de ocorrência. Ela pode estar em alguns formatos --- separada por barras ou por extenso. Exemplos: "12/12/2004" e "12 de dezembro de 2004".
# 3. Lista de acusados (*Acusados*): cada processo tem a ele associado uma lista de acusados, que pode conter um ou mais nomes, sendo eles pessoas físicas ou jurídicas. O objetivo é colher, para cada documento, a lista de acusados associada. Armazenamos a informação no formato de uma lista dentro da base de dados. Exemplo colhido de um processo: "[Letícia Ferreira Duarte do Valle, Le Valle Agente Autônomo de Investimentos S/S Ltda.]".
# 4. Assunto ou ementa (*Assunto*): no cabeçalho de cada processo, temos uma breve descrição dos fatos. Normalmente, tem de 1 a 4 parágrafos e é importante, pois dá uma visão geral do que está sendo julgado no processo. Exemplo de um processo: "Emissão de Parecer sem Abstenção de Opinião, em descumprimento ao item 21 da NBC T11-IT5, aprovada pela Resolução CFC Nº 830/98, que, por seu turno, representa uma infração ao art. 20 da Instrução CVM nº 308/99. Multas."
# 5. Decisão (*Decisão*): no cabeçalho, normalmente depois do assunto, temos uma breve descrição da decisão do Colegiado na Sessão de Julgamento. Exemplo, extraído de um processo: "Vistos, relatados e discutidos os autos, o Colegiado da Comissão de Valores Mobiliários, com base na prova dos autos e na legislação aplicável, por maioria de votos, decidiu aplicar aos acusados BC Control Auditores Independentes S/S e Sandro Casagrande a penalidade de multa pecuniária individual no valor de R$ 75.000,00, pelo descumprimento do item 21 da NBC T11-IT 5, que representa infração ao art. 20 da Instrução CVM nº 308/99."
#
# ## Método
# Usamos o pacote *pdfplumber* para colher as informações. Além disso, usamos expressões regulares para delimitar cada um dos tópicos do documento. Essas serão exploradas mais a fundo.
#
# A análise foi feita com base no texto das duas primeiras páginas. Apesar desse limite não ser oficial, para todos os processos que observamos, o "cabeçalho" (parte que contém essas 5 informações ou a maioria delas) estava contido nesse limite.
#
# O código foi construído com base em uma amostra escolhida aleatoriamente (n = 20, seed = 42) dentre os processos. A partir dessa amostra e da análise dos documentos nela presentes, as expressões regulares e a ordem e os métodos de colheita de informações foram adaptados, de forma a ter a maior eficiência possível, dentro da amostra. Se ela for representativa (acreditamos que, até certo ponto, depois de inúmeras leituras "na diagonal", ela seja), esperamos conseguir resultados semelhantes ao generalizar o código para todos os arquivos entre 2000 e 2023. Esse código também está disponível no Github.
#
# Agora, vamos analisar os critérios utilizados, por variável:
#
# ### *ID*:
# Para coletar o ID dos processos, usamos o nome (do arquivo) de cada um dos PDFs. Ao baixar a pasta com os arquivos dos Extratos das Sessões de Julgamento, notamos que os nomes estavam muito bem padronizados, para cada um dos documentos. Portanto, o que o código faz, para cada um dos documentos, é coletar o nome do arquivo e adicioná-lo à coluna de *ID*.
#
# Na amostra aleatória que colhemos, tivemos 100% dos identificadores de processo colhidos, dos quais 100% estavam corretos.
#
# ### *Data*:
# Para colher as datas do julgamento, usamos expressões regulares que foram construídas com base na observação da amostra.
#
# Para processos mais recentes, é fácil notar que, normalmente, as primeiras páginas se iniciam com a expressão "Data do julgamento: XX/XX/20XX". Para todos os processos que tinham essa expressão regular, extraímos exatamente essa expressão.
#
# Já para os processos mais antigos, normalmente a parte preliminar dos documentos termina com a data, por extenso, da seguinte forma: "Rio de Janeiro, XX de mês (janeiro, fevereiro, etc.) de 20XX." Usamos essa expressão regular, quando contida nas duas primeiras páginas, para extrair a data da Sessão de Julgamento daquele PAS.
#
# Sobre a eficácia: para a amostra de 20 arquivos, colhemos a data em 18 (90%) e ela estava correta em todas as ocasiões em que foi colhida. Para os outros dois arquivos, não conseguimos colher a data porque ela não estava disponível nas duas primeiras páginas do documento (o documento estava desconfigurado). Em um dos documentos, por exemplo, a data estava na página 10. Isso exigiria uma capacidade computacional e um tempo de processamento que é desnecessariamente grande (é melhor extrair as informações faltantes manualmente).
#
# ### *Acusados*:
# Novamente, usamos expressões regulares com base na observação da amostra. Na maior parte dos arquivos, notamos que a lista de acusados vem no formato "Acusados/Interessados/Indiciados: XXXX", seguida do assunto/ementa. Configuramos as expressões regulares com base nisso.
#
# Sobre a eficácia: para a amostra de 20 arquivos, coletamos a lista de acusados em 20 (100%) e ela estava correta para 20 dos 20 arquivos (100%). Até mesmo os arquivos desfigurados, mencionados na seção anterior, tinham uma lista de acusados nas primeiras páginas. Por isso, imaginando uma amostra representativa, esperamos ter boa acurácia nesse tópico.
#
# A lista de acusados colhida de maneira errônea foi graças a uma vírgula no meio do nome de uma empresa, de forma que o seu nome ("New Way Técnicas Administrativas, Assessoria e Planejamento Ltda.") ficasse separado em duas strings, pela vírgula. Acreditamos que a probabilidade de ocorrência desse tipo de erro seja baixa para a maior parte dos processos, mas é um tópico de atenção.
#
# ### *Assunto*:
# Para captar o assunto dos processos, usamos expressões regulares. Notamos que, normalmente, o assunto segue um formato padrão: "Assunto/Ementa: XXX", e está seguido da palavra "Decisão".
#
# Para o teste com a amostra de 20 arquivos, captamos o assunto de 18 (90%), dentre os quais 18 estavam corretos (100%). Os arquivos com os quais tivemos problemas foram os mesmos da seção de datas, graças à desfiguração. Ela vai ser discutida na seção posterior.
#
# ### *Decisão*:
# Normalmente, a decisão é introduzida sempre pela frase "Vistos, relatados e discutidos os autos". Usamos essa expressão regular para iniciar a captura. Ela estava presente em todas as decisões que captamos.
#
# Além disso, normalmente termina com uma expressão específica. Normalmente, depois de relatar a decisão, o relator dá o prazo para apresentação de recursos (30 dias, em todos os arquivos que observamos). Por isso, usamos a expressão "30 dias" e suas variações como uma das "stopwords". Outra expressão muito usada é a data da sessão de julgamento, no formato por extenso. Usamos ela também. Além disso, em alguns casos, especialmente nos documentos mais recentes que analisamos, temos a expressão "Participaram desta Sessão", ou o fim da segunda página, como o fim da parte inicial dos autos.
#
# Para o teste com a amostra de 20 arquivos, captamos a decisão em 18 (90%), dentre as quais todas continham as partes que julgamos relevantes (100%). Novamente, o problema foi na captação da decisão dos mesmos dois arquivos desfigurados. Apesar disso, houve, em muitos casos, a captura de mais texto do que necessário (uma frase ou alguns parágrafos a mais). Isso é um ponto de atenção, mas em todos os casos a decisão foi captada por completo (acreditamos que o limite de duas páginas na análise dos documentos foi importante nesse sentido).
#
# ## Possíveis perdas de dados (desconfiguração, documentos escaneados, etc.)
# Como comentado na seção anterior, observamos, para dois documentos, problemas na colheita dos dados. Em ambos os casos, os documentos não tinham a primeira página na estrutura que esperávamos (Acusados, Assunto, Decisão). Muito pelo contrário. O que aconteceu foi que não conseguimos colher esses dados porque eles não existiam dentro dos arquivos. Apesar disso, os dados disponíveis foram completamente colhidos. Isso, acreditamos, é um indicativo de sucesso na acurácia do código (nenhuma informação falsa/incorreta colhida, nenhum "falso positivo").
#
# No entanto, é importante saber, obviamente, que o código em questão não será capaz de colher a totalidade das informações dentro da pasta de mais de 900 arquivos baixados do site da CVM, mas acreditamos que boa parte estará lá.
#
# Outro problema que certamente vamos enfrentar: uma pequena parte (só nos deparamos com um até o momento) dos processos são imagens escaneadas dos autos dos processos. Nesse caso, o código não vai funcionar e as informações terão de ser registradas manualmente.

# %% [markdown]
# ----------

# %% [markdown]
# Vamos importar os pacotes a serem usados:

# %%
import os
import fitz
import pandas as pd
import re
import random
import shutil
import pdfplumber
from PyPDF2 import PdfReader
import numpy as np
import time

# %% [markdown]
# Vamos definir o caminho para a pasta que contém os arquivos:

# %%
# Caminho para a pasta principal com subpastas de anos
pasta_principal = "T:/T0mas/Faculdade/Bolsa PUB/Data"  # Altere para o caminho da sua pasta principal

# %% [markdown]
# Vamos ver com quantos arquivos estamos trabalhando.

# %%
# Dicionário para armazenar a contagem de arquivos por ano
contagem_arquivos = {}

# Contador total
total_arquivos = 0

# Loop pelas subpastas de anos (2000 a 2023)
for ano in range(2000, 2024):
    subpasta = os.path.join(pasta_principal, str(ano))  # Caminho para a subpasta do ano
    
    if os.path.exists(subpasta):  # Verifica se a subpasta existe
        # Contar arquivos PDF na subpasta
        arquivos_pdf = [arquivo for arquivo in os.listdir(subpasta) if arquivo.endswith('.pdf')]
        quantidade = len(arquivos_pdf)
        contagem_arquivos[ano] = quantidade
        total_arquivos += quantidade  # Soma ao total
    else:
        contagem_arquivos[ano] = 0  # Se a subpasta não existir, define contagem como 0

# Exibir os resultados
for ano, quantidade in contagem_arquivos.items():
    print(f"Ano {ano}: {quantidade} arquivos PDF")

print(f"\nNúmero total de arquivos PDF entre 2000 e 2023: {total_arquivos}")
# Out:
# Ano 2000: 19 arquivos PDF
# Ano 2001: 36 arquivos PDF
# Ano 2002: 30 arquivos PDF
# Ano 2003: 41 arquivos PDF
# Ano 2004: 62 arquivos PDF
# Ano 2005: 80 arquivos PDF
# Ano 2006: 110 arquivos PDF
# Ano 2007: 58 arquivos PDF
# Ano 2008: 35 arquivos PDF
# Ano 2009: 48 arquivos PDF
# Ano 2010: 45 arquivos PDF
# Ano 2011: 24 arquivos PDF
# Ano 2012: 25 arquivos PDF
# Ano 2013: 57 arquivos PDF
# Ano 2014: 41 arquivos PDF
# Ano 2015: 55 arquivos PDF
# Ano 2016: 62 arquivos PDF
# Ano 2017: 50 arquivos PDF
# Ano 2018: 98 arquivos PDF
# Ano 2019: 99 arquivos PDF
# Ano 2020: 66 arquivos PDF
# Ano 2021: 23 arquivos PDF
# Ano 2022: 50 arquivos PDF
# Ano 2023: 57 arquivos PDF
#
# Número total de arquivos PDF entre 2000 e 2023: 1271

# %% [markdown]
# Primeiro, definimos a função que vamos usar. Ela é a mesma do outro código.

# %%
# Função para extrair as informações de cada PDF
def extrair_informacoes_pdf(caminho_pdf):
    nome_arquivo = os.path.basename(caminho_pdf)
    pattern_processo_nome_arquivo = r"(?:\d{5}-\d{6}-\d{4}-\d{2}|IA-\d{4}-\d{2}|RJ-\d{4}-\d{5}|SP-\d{4}-\d{5})"
    match_processo_nome_arquivo = re.search(pattern_processo_nome_arquivo, nome_arquivo)
    numero_processo = match_processo_nome_arquivo.group(0) if match_processo_nome_arquivo else np.nan

    with pdfplumber.open(caminho_pdf) as pdf:
        text = ""
        for i in range(min(2, len(pdf.pages))):
            page = pdf.pages[i]
            text += page.extract_text()

    text = re.sub(r"Extrato de Sessão de Julgamento.*?\n", "", text, flags=re.DOTALL)
    text = re.sub(r"https:\/\/.*\n", "", text)

    pattern_data_julgamento = r"(Data do julgamento:\s*(\d{2}/\d{2}/\d{4})|(?:Rio de Janeiro|São Paulo|Brasília),\s*(\d{2} de (?:janeiro|fevereiro|março|abril|maio|junho|julho|agosto|setembro|outubro|novembro|dezembro) de 20\d{2}))"
    pattern_acusados = r"(?:Acusados?\s*:|Interessados?\s*:|Indiciados?\s*:|ACUSADOS?\s*:|INTERESSADOS?\s*:|INDICIADOS?\s*:)\s*(.+?)(?=\s*(Assunto|Ementa|Relator|ASSUNTO|EMENTA|RELATOR))"
    pattern_assunto = r"(?:Assunto\s*:|Ementa\s*:|ASSUNTO\s*:|EMENTA\s*:)\s*(.+?)(?=\s*(Decisão|DECISÃO))" 
    pattern_decisao = r"(Vistos, relatados e discutidos os autos\s*(.+?))(?=\s*(?:30 dias|30 (trinta) dias|trinta dias|Participaram desta Sessão|(Rio de Janeiro|São Paulo|Brasília), \d{2} de (janeiro|fevereiro|março|abril|maio|junho|julho|agosto|setembro|outubro|novembro|dezembro) de 20\d{2}))"

    match_data_julgamento = re.search(pattern_data_julgamento, text)
    match_acusados = re.search(pattern_acusados, text, re.DOTALL)
    match_assunto = re.search(pattern_assunto, text, re.DOTALL)
    match_decisao = re.search(pattern_decisao, text, re.DOTALL)

    data_julgamento = match_data_julgamento.group(1).strip() if match_data_julgamento else np.nan
    acusados = match_acusados.group(1).strip() if match_acusados else np.nan
    assunto = " ".join(match_assunto.group(1).strip().splitlines()) if match_assunto else np.nan
    decisao = " ".join(match_decisao.group(1).strip().splitlines()) if match_decisao else np.nan

    return numero_processo, data_julgamento, acusados, assunto, decisao

# %% [markdown]
# Agora, vamos fazer o loop que vai abrir as pastas de 2000 a 2024 e rodar a função para cada um dos arquivos dentro delas. Depois, ele vai adicionar tudo em um dataframe do pandas, que vamos exportar posteriormente.

# %%
# Lista para acumular os dados
dados = []

# Iniciar o timer total
start_time = time.time()

# Loop pelas subpastas de anos (2000 a 2023)
for ano in range(2000, 2024):
    subpasta = os.path.join(pasta_principal, str(ano))  # Caminho para a subpasta do ano
    
    if os.path.exists(subpasta):  # Verifica se a subpasta existe
        for arquivo in os.listdir(subpasta):  # Lista todos os arquivos na subpasta
            if arquivo.endswith('.pdf'):
                caminho_pdf = os.path.join(subpasta, arquivo)

                # Timer para cada iteração
                iter_start = time.time()

                try:
                    # Extrair informações do PDF
                    numero_processo, data_julgamento, acusados, assunto, decisao = extrair_informacoes_pdf(caminho_pdf)

                    # Criar lista de acusados
                    if isinstance(acusados, str):
                        pattern_nome_acusados = r"[^,\n]+(?:,[^,\n]+)*"  # Captura texto até o próximo '\n' ou vírgula interna
                        acusados_lista = [match.group(0).strip() for match in re.finditer(pattern_nome_acusados, acusados)]
                    else:
                        acusados_lista = []

                    # Adicionar dados à lista
                    dados.append({
                        "ID": numero_processo,
                        "Data": data_julgamento,
                        "Acusados": acusados_lista,
                        "Assunto": assunto,
                        "Decisão": decisao
                    })

                except Exception as e:
                    print(f"Erro ao processar {arquivo} na pasta {subpasta}: {e}")
                    continue

                # Timer de cada iteração
                iter_end = time.time()
                iter_time = iter_end - iter_start
                print(f"Tempo para processar {arquivo} da pasta {subpasta}: {iter_time:.2f} segundos")

# Criar o DataFrame com todos os dados
df = pd.DataFrame(dados)

# Calcular o tempo total
end_time = time.time()
execution_time = end_time - start_time
print(f"Tempo total de execução: {execution_time:.2f} segundos")

# Exibir o DataFrame com todos os resultados
df
# Out:
# Tempo para processar IA-1995-21.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2000: 0.53 segundos
# Tempo para processar IA-1996-10.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2000: 0.65 segundos
# Tempo para processar IA-1997-12.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2000: 0.97 segundos
# Tempo para processar IA-1998-01.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2000: 0.73 segundos
# Tempo para processar IA-1998-05_B.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2000: 0.54 segundos
# Tempo para processar IA-1998-13.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2000: 0.73 segundos
# Tempo para processar IA-1998-17.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2000: 0.66 segundos
# Tempo para processar IA-1998-33.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2000: 0.67 segundos
# Tempo para processar IA-1998-35.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2000: 0.79 segundos
# Tempo para processar IA-1998-36_A.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2000: 0.77 segundos
# Tempo para processar IA-1999-05.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2000: 0.55 segundos
# Tempo para processar IA-1999-08.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2000: 0.88 segundos
# Tempo para processar IA-1999-09.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2000: 0.57 segundos
# Tempo para processar IA-1999-10.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2000: 0.87 segundos
# Tempo para processar IA-1999-14.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2000: 0.82 segundos
# Tempo para processar IA-1999-16.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2000: 0.59 segundos
# Tempo para processar IA-1999-19.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2000: 0.77 segundos
# Tempo para processar IA-1999-23.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2000: 0.70 segundos
# Tempo para processar IA-1999-25.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2000: 0.61 segundos
# Tempo para processar IA-1997-11.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2001: 0.39 segundos
# Tempo para processar IA-1997-15.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2001: 0.36 segundos
# Tempo para processar IA-1998-08.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2001: 0.67 segundos
# Tempo para processar IA-1998-19.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2001: 0.62 segundos
# Tempo para processar IA-1998-20.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2001: 0.72 segundos
# Tempo para processar IA-1998-24.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2001: 0.78 segundos
# Tempo para processar IA-1998-25.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2001: 0.52 segundos
# Tempo para processar IA-1998-29.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2001: 0.58 segundos
# Tempo para processar IA-1998-30.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2001: 0.66 segundos
# Tempo para processar IA-1998-36_B.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2001: 0.55 segundos
# Tempo para processar IA-1998-38.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2001: 0.72 segundos
# Tempo para processar IA-1998-39.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2001: 0.51 segundos
# Tempo para processar IA-1999-01.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2001: 1.00 segundos
# Tempo para processar IA-1999-02.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2001: 0.65 segundos
# Tempo para processar IA-1999-03.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2001: 0.80 segundos
# Tempo para processar IA-1999-13.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2001: 0.65 segundos
# Tempo para processar IA-1999-15.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2001: 0.87 segundos
# Tempo para processar IA-1999-17.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2001: 0.95 segundos
# Tempo para processar IA-1999-18.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2001: 0.51 segundos
# Tempo para processar IA-1999-22.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2001: 0.88 segundos
# Tempo para processar IA-1999-26.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2001: 0.69 segundos
# Tempo para processar IA-1999-29.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2001: 0.73 segundos
# Tempo para processar IA-1999-30.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2001: 0.61 segundos
# Tempo para processar IA-1999-33.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2001: 0.75 segundos
# Tempo para processar IA-1999-34.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2001: 0.77 segundos
# Tempo para processar IA-2000-02.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2001: 0.76 segundos
# Tempo para processar IA-2000-03.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2001: 0.59 segundos
# Tempo para processar IA-2000-07.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2001: 0.80 segundos
# Tempo para processar IA-2000-20.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2001: 0
pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2003: 0.87 segundos
# Tempo para processar RJ-2002-06982.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2003: 0.87 segundos
# Tempo para processar RJ-2003-00435.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2003: 0.88 segundos
# Tempo para processar RJ-2003-04953.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2003: 1.04 segundos
# Tempo para processar RJ-2003-05486.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2003: 0.86 segundos
# Tempo para processar SP-2001-00307.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2003: 0.78 segundos
# Tempo para processar SP-2001-00386.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2003: 0.70 segundos
# Tempo para processar SP-2001-00395.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2003: 0.74 segundos
# Tempo para processar SP-2001-00725.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2003: 0.80 segundos
# Tempo para processar SP-2002-00047.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2003: 0.73 segundos
# Tempo para processar SP-2002-00048.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2003: 0.79 segundos
# Tempo para processar SP-2002-00098.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2003: 0.90 segundos
# Tempo para processar SP-2002-00257.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2003: 0.75 segundos
# Tempo para processar SP-2002-00397.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2003: 0.80 segundos
# Tempo para processar SP-2002-00564.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2003: 0.84 segundos
# Tempo para processar SP-2003-00148.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2003: 1.11 segundos
# Tempo para processar IA-1994-22.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 1.45 segundos
# Tempo para processar IA-1996-03.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 0.70 segundos
# Tempo para processar IA-1997-03.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 0.82 segundos
# Tempo para processar IA-1998-12.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 0.70 segundos
# Tempo para processar IA-1998-32.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 0.63 segundos
# Tempo para processar IA-1998-34.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 0.76 segundos
# Tempo para processar IA-1999-21.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 0.61 segundos
# Tempo para processar IA-1999-27.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 0.63 segundos
# Tempo para processar IA-2000-05.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 0.80 segundos
# Tempo para processar IA-2000-09.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 0.63 segundos
# Tempo para processar IA-2000-10.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 0.51 segundos
# Tempo para processar IA-2000-14.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 0.77 segundos
# Tempo para processar IA-2000-17.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 0.53 segundos
# Tempo para processar IA-2000-21.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 0.83 segundos
# Tempo para processar IA-2000-25.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 0.98 segundos
# Tempo para processar IA-2000-27.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 0.92 segundos
# Tempo para processar IA-2000-34.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 0.81 segundos
# Tempo para processar IA-2000-37.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 1.35 segundos
# Tempo para processar IA-2001-05.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 0.69 segundos
# Tempo para processar IA-2001-06.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 0.97 segundos
# Tempo para processar IA-2001-08.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 0.46 segundos
# Tempo para processar IA-2001-18.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 0.51 segundos
# Tempo para processar IA-2002-03.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 0.86 segundos
# Tempo para processar IA-2002-05.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 1.35 segundos
# Tempo para processar IA-2002-07.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 0.53 segundos
# Tempo para processar IA-2002-10.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 0.92 segundos
# Tempo para processar RJ-2001-04635.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 0.56 segundos
# Tempo para processar RJ-2001-07557.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 0.58 segundos
# Tempo para processar RJ-2001-07749.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 1.44 segundos
# Tempo para processar RJ-2001-08029.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 0.73 segundos
# Tempo para processar RJ-2001-08473.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 0.81 segundos
# Tempo para processar RJ-2001-09686.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 0.69 segundos
# Tempo para processar RJ-2002-00445.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 1.42 segundos
# Tempo para processar RJ-2002-01846.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 1.25 segundos
# Tempo para processar RJ-2002-03087.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 0.64 segundos
# Tempo para processar RJ-2002-04936.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 0.70 segundos
# Tempo para processar RJ-2002-05113.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 0.81 segundos
# Tempo para processar RJ-2002-06738.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 0.61 segundos
# Tempo para processar RJ-2002-07539.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 0.80 segundos
# Tempo para processar RJ-2002-07635.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 0.99 segundos
# Tempo para processar RJ-2002-08428.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 0.58 segundos
# Tempo para processar RJ-2003-05753.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 0.74 segundos
# Tempo para processar RJ-2003-08172.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 0.48 segundos
# Tempo para processar RJ-2003-12818.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 0.69 segundos
# Tempo para processar RJ-2003-13210.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 1.27 segundos
# Tempo para processar RJ-2004-01844.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 0.83 segundos
# Tempo para processar RJ-2004-03456.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 0.79 segundos
# Tempo para processar RJ-2004-05131.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 0.70 segundos
# Tempo para processar SP-2001-00034.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 0.52 segundos
# Tempo para processar SP-2001-00236.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 2.13 segundos
# Tempo para processar SP-2001-00240.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 1.53 segundos
# Tempo para processar SP-2001-00373.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 1.05 segundos
# Tempo para processar SP-2001-00465.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 1.22 segundos
# Tempo para processar SP-2002-00197.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 1.32 segundos
# Tempo para processar SP-2002-00462.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 0.77 segundos
# Tempo para processar SP-2002-00487.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 0.73 segundos
# Tempo para processar SP-2003-00042.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 0.84 segundos
# Tempo para processar SP-2003-00100.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 1.27 segundos
# Tempo para processar SP-2003-00288.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 1.68 segundos
# Tempo para processar SP-2003-00446.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 0.79 segundos
# Tempo para processar SP-2004-00113.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 0.80 segundos
# Tempo para processar SP-2004-00123.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2004: 1.39 segundos
# Tempo para processar IA-1995-06.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.67 segundos
# Tempo para processar IA-1996-11.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.38 segundos
# Tempo para processar IA-1997-17_A.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.62 segundos
# Tempo para processar IA-1997-17_B.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.81 segundos
# Tempo para processar IA-1998-31.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.74 segundos
# Tempo para processar IA-2000-04.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.51 segundos
# Tempo para processar IA-2000-24.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.69 segundos
# Tempo para processar IA-2000-35.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.94 segundos
# Tempo para processar IA-2000-39.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.50 segundos
# Tempo para processar IA-2001-04.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.44 segundos
# Tempo para processar IA-2001-07.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.77 segundos
# Tempo para processar IA-2001-14.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.67 segundos
# Tempo para processar IA-2001-16.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.74 segundos
# Tempo para processar IA-2002-01.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.61 segundos
# Tempo para processar IA-2002-06.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.72 segundos
# Tempo para processar IA-2002-17.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.63 segundos
# Tempo para processar IA-2003-04.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.98 segundos
# Tempo para processar IA-2003-06.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.87 segundos
# Tempo para processar IA-2003-10.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.86 segundos
# Tempo para processar IA-2003-13.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.88 segundos
# Tempo para processar IA-2003-18.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.86 segundos
# Tempo para processar IA-2003-24.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.79 segundos
# Tempo para processar IA-2003-27.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.45 segundos
# Tempo para processar IA-2004-01.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.79 segundos
# Tempo para processar IA-2004-02.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.63 segundos
# Tempo para processar IA-2004-11.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.87 segundos
# Tempo para processar RJ-2001-04474.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.85 segundos
# Tempo para processar RJ-2001-08028.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.62 segundos
# Tempo para processar RJ-2001-08363.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.87 segundos
# Tempo para processar RJ-2001-11949.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.56 segundos
# Tempo para processar RJ-2002-01415.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.70 segundos
# Tempo para processar RJ-2002-01822.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.76 segundos
# Tempo para processar RJ-2002-01823.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.52 segundos
# Tempo para processar RJ-2002-02047.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.59 segundos
# Tempo para processar RJ-2002-04985.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.77 segundos
# Tempo para processar RJ-2002-06413.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.78 segundos
# Tempo para processar RJ-2003-00823.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.66 segundos
# Tempo para processar RJ-2003-01631.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.87 segundos
# Tempo para processar RJ-2003-05058.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 1.36 segundos
# Tempo para processar RJ-2003-05509.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.98 segundos
# Tempo para processar RJ-2003-05596.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 1.03 segundos
# Tempo para processar RJ-2003-05627.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.84 segundos
# Tempo para processar RJ-2003-05849.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.85 segundos
# Tempo para processar RJ-2003-06098.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.92 segundos
# Tempo para processar RJ-2003-06894.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.91 segundos
# Tempo para processar RJ-2003-07642.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.99 segundos
# Tempo para processar RJ-2003-07697.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.96 segundos
# Tempo para processar RJ-2003-11503.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.83 segundos
# Tempo para processar RJ-2003-12233.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.82 segundos
# Tempo para processar RJ-2003-12312.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 2.01 segundos
# Tempo para processar RJ-2003-12911.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.85 segundos
# Tempo para processar RJ-2004-02132.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.97 segundos
# Tempo para processar RJ-2004-03169.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.87 segundos
# Tempo para processar RJ-2004-04627.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.99 segundos
# Tempo para processar RJ-2004-05238.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.46 segundos
# Tempo para processar RJ-2004-06238.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.89 segundos
# Tempo para processar RJ-2004-07001.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 1.04 segundos
# Tempo para processar RJ-2005-00033.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.86 segundos
# Tempo para processar RJ-2005-01860.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 1.05 segundos
# Tempo para processar RJ-2005-01952.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.21 segundos
# Tempo para processar RJ-2005-02793.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.97 segundos
# Tempo para processar RJ-2005-02815.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.73 segundos
# Tempo para processar RJ-2005-03106.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 1.28 segundos
# Tempo para processar RJ-2005-03646.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.91 segundos
# Tempo para processar RJ-2005-03711.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.68 segundos
# Tempo para processar RJ-2005-03750.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.93 segundos
# Tempo para processar RJ-2005-04215.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.78 segundos
# Tempo para processar RJ-2005-05204.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.93 segundos
# Tempo para processar SP-2001-00799.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.74 segundos
# Tempo para processar SP-2002-00049.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.85 segundos
# Tempo para processar SP-2002-00493.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.61 segundos
# Tempo para processar SP-2003-00070.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.59 segundos
# Tempo para processar SP-2003-00313.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.93 segundos
# Tempo para processar SP-2003-00324.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.90 segundos
# Tempo para processar SP-2003-00444.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.82 segundos
# Tempo para processar SP-2003-00445.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.73 segundos
# Tempo para processar SP-2003-00466.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.46 segundos
# Tempo para processar SP-2004-00104.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.29 segundos
# Tempo para processar SP-2004-00154.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.85 segundos
# Tempo para processar SP-2005-00158.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2005: 0.88 segundos
# Tempo para processar IA-1993-09.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0.86 segundos
# Tempo para processar IA-1995-03.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0.79 segundos
# Tempo para processar IA-1996-22.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0.65 segundos
# Tempo para processar IA-1997-09.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0.27 segundos
# Tempo para processar IA-1999-32.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0.53 segundos
# Tempo para processar IA-2000-30.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0.79 segundos
# Tempo para processar IA-2001-12.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0.90 segundos
# Tempo para processar IA-2001-13.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0.60 segundos
# Tempo para processar IA-2002-09.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0.77 segundos
# Tempo para processar IA-2002-13.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0.74 segundos
# Tempo para processar IA-2002-16.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0.69 segundos
# Tempo para processar IA-2003-03.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0.79 segundos
# Tempo para processar IA-2003-09.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0.54 segundos
# Tempo para processar IA-2003-16.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0.81 segundos
# Tempo para processar IA-2003-28.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0.66 segundos
# Tempo para processar IA-2004-04.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0.84 segundos
# Tempo para processar IA-2004-09.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0.74 segundos
# Tempo para processar IA-2004-23.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0.92 segundos
# Tempo para processar IA-2005-04.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0.91 segundos
# Tempo para processar IA-2005-09.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0.95 segundos
# Tempo para processar IA-2005-15.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 1.02 segundos
# Tempo para processar RJ-2002-04311.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0.83 segundos
# Tempo para processar RJ-2002-04879.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0.98 segundos
# Tempo para processar RJ-2002-05516.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0.88 segundos
# Tempo para processar RJ-2002-06032.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0.82 segundos
# Tempo para processar RJ-2002-06118.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0.88 segundos
# Tempo para processar RJ-2003-04367.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0.83 segundos
# Tempo para processar RJ-2003-05137.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0.66 segundos
# Tempo para processar RJ-2003-05669.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0.73 segundos
# Tempo para processar RJ-2003-12406.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0.86 segundos
# Tempo para processar RJ-2003-12656.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0.87 segundos
# Tempo para processar RJ-2004-00210.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0.91 segundos
# Tempo para processar RJ-2004-00852.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0.82 segundos
# Tempo para processar RJ-2004-01278.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0
pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0.73 segundos
# Tempo para processar SP-2003-00175.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0.98 segundos
# Tempo para processar SP-2003-00205.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0.80 segundos
# Tempo para processar SP-2003-00314.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0.94 segundos
# Tempo para processar SP-2003-00461.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0.85 segundos
# Tempo para processar SP-2003-00489.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0.68 segundos
# Tempo para processar SP-2004-00106.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0.93 segundos
# Tempo para processar SP-2004-00185.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0.76 segundos
# Tempo para processar SP-2004-00197.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0.71 segundos
# Tempo para processar SP-2004-00543.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0.81 segundos
# Tempo para processar SP-2004-00693.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0.24 segundos
# Tempo para processar SP-2005-00128.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0.82 segundos
# Tempo para processar SP-2005-00188.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0.81 segundos
# Tempo para processar SP-2005-00296.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0.66 segundos
# Tempo para processar SP-2005-00371.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2006: 0.68 segundos
# Tempo para processar IA-2002-02.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.82 segundos
# Tempo para processar IA-2002-15.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.97 segundos
# Tempo para processar IA-2003-01.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.81 segundos
# Tempo para processar IA-2003-02.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.75 segundos
# Tempo para processar IA-2003-07.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.53 segundos
# Tempo para processar IA-2003-14.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.58 segundos
# Tempo para processar IA-2003-19.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.61 segundos
# Tempo para processar IA-2003-29.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.81 segundos
# Tempo para processar IA-2004-03.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.70 segundos
# Tempo para processar IA-2004-05.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.57 segundos
# Tempo para processar IA-2004-07.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.78 segundos
# Tempo para processar IA-2004-21.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.67 segundos
# Tempo para processar IA-2004-22.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.68 segundos
# Tempo para processar IA-2004-24.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.65 segundos
# Tempo para processar IA-2005-07.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.85 segundos
# Tempo para processar IA-2005-08.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.04 segundos
# Tempo para processar IA-2005-23.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.70 segundos
# Tempo para processar IA-2005-28.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.84 segundos
# Tempo para processar RJ-2001-11808.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.79 segundos
# Tempo para processar RJ-2003-13021.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.69 segundos
# Tempo para processar RJ-2005-00097.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.67 segundos
# Tempo para processar RJ-2005-00098.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.89 segundos
# Tempo para processar RJ-2005-05442.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.68 segundos
# Tempo para processar RJ-2005-06763.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.62 segundos
# Tempo para processar RJ-2005-07521.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.98 segundos
# Tempo para processar RJ-2005-08510.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.79 segundos
# Tempo para processar RJ-2005-08528.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.84 segundos
# Tempo para processar RJ-2005-08604.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.46 segundos
# Tempo para processar RJ-2005-08714.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.87 segundos
# Tempo para processar RJ-2005-09245.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.53 segundos
# Tempo para processar RJ-2005-09831.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.74 segundos
# Tempo para processar RJ-2006-01216.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.72 segundos
# Tempo para processar RJ-2006-03364.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.68 segundos
# Tempo para processar RJ-2006-03565.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.91 segundos
# Tempo para processar RJ-2006-04321.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.92 segundos
# Tempo para processar RJ-2006-04663.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.81 segundos
# Tempo para processar RJ-2006-04776.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.78 segundos
# Tempo para processar RJ-2006-04850.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.68 segundos
# Tempo para processar RJ-2006-05853.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.73 segundos
# Tempo para processar RJ-2006-05863.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.86 segundos
# Tempo para processar RJ-2006-05928.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.95 segundos
# Tempo para processar RJ-2006-06017.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.78 segundos
# Tempo para processar RJ-2006-06652.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.92 segundos
# Tempo para processar RJ-2006-07655.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.87 segundos
# Tempo para processar RJ-2006-09068.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.71 segundos
# Tempo para processar RJ-2007-01079.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.77 segundos
# Tempo para processar RJ-2007-01176.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.71 segundos
# Tempo para processar RJ-2007-03639.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 1.03 segundos
# Tempo para processar RJ-2007-07406.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.86 segundos
# Tempo para processar SP-2004-00193.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.59 segundos
# Tempo para processar SP-2004-00602.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.81 segundos
# Tempo para processar SP-2005-00155.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.64 segundos
# Tempo para processar SP-2005-00180.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.62 segundos
# Tempo para processar SP-2005-00338.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.81 segundos
# Tempo para processar SP-2006-00143.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.69 segundos
# Tempo para processar SP-2006-00160.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.68 segundos
# Tempo para processar SP-2006-00169.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.77 segundos
# Tempo para processar SP-2006-00174.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2007: 0.74 segundos
# Tempo para processar IA-2003-25.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2008: 0.53 segundos
# Tempo para processar IA-2004-20.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2008: 0.82 segundos
# Tempo para processar IA-2004-25.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2008: 0.65 segundos
# Tempo para processar IA-2005-01.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2008: 0.50 segundos
# Tempo para processar IA-2005-03.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2008: 0.30 segundos
# Tempo para processar IA-2005-22.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2008: 0.86 segundos
# Tempo para processar IA-2005-24.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2008: 0.73 segundos
# Tempo para processar IA-2005-29.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2008: 0.99 segundos
# Tempo para processar IA-2006-01.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2008: 0.54 segundos
# Tempo para processar IA-2006-11.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2008: 0.91 segundos
# Tempo para processar IA-2006-15.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2008: 0.69 segundos
# Tempo para processar RJ-2006-04849.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2008: 0.91 segundos
# Tempo para processar RJ-2006-05136.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2008: 0.84 segundos
# Tempo para processar RJ-2006-05343.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2008: 0.85 segundos
# Tempo para processar RJ-2006-05410.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2008: 0.79 segundos
# Tempo para processar RJ-2006-09070.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2008: 0.73 segundos
# Tempo para processar RJ-2007-00974.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2008: 0.90 segundos
# Tempo para processar RJ-2007-02966.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2008: 0.79 segundos
# Tempo para processar RJ-2007-03613.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2008: 0.90 segundos
# Tempo para processar RJ-2007-03822.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2008: 0.71 segundos
# Tempo para processar RJ-2007-04107.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2008: 0.79 segundos
# Tempo para processar RJ-2007-04476.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2008: 0.70 segundos
# Tempo para processar RJ-2007-08109.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2008: 0.69 segundos
# Tempo para processar RJ-2007-09559.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2008: 0.72 segundos
# Tempo para processar RJ-2007-10843.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2008: 0.84 segundos
# Tempo para processar RJ-2007-11851.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2008: 0.81 segundos
# Tempo para processar RJ-2007-12545.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2008: 0.60 segundos
# Tempo para processar RJ-2007-13207.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2008: 0.75 segundos
# Tempo para processar RJ-2007-14044.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2008: 0.81 segundos
# Tempo para processar RJ-2008-00970.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2008: 0.56 segundos
# Tempo para processar RJ-2008-02530.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2008: 0.91 segundos
# Tempo para processar SP-2006-00168.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2008: 0.84 segundos
# Tempo para processar SP-2007-00114.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2008: 0.86 segundos
# Tempo para processar SP-2007-00117.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2008: 0.78 segundos
# Tempo para processar SP-2007-00118.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2008: 0.78 segundos
# Tempo para processar IA-2003-20.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2009: 0.84 segundos
# Tempo para processar IA-2004-15.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2009: 0.70 segundos
# Tempo para processar IA-2005-10.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2009: 0.85 segundos
# Tempo para processar IA-2005-14.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2009: 0.36 segundos
# ...
# Tempo para processar 19957-010135-2018-40 (RJ-2018-07396).pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2021: 0.41 segundos
# Tempo para processar 19957-010505-2018-49 (RJ-2018-07872).pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2021: 0.54 segundos
# Tempo para processar 19957-010573-2019-99 (RJ-2020-01228).pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2021: 0.43 segundos
# Tempo para processar 19957-010637-2019-51 (RJ-2015-02386).pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2021: 0.61 segundos
# Tempo para processar 19957-010833-2018-45 (RJ-2018-08272).pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2021: 0.42 segundos
# Tempo para processar 19957-011101-2019-53 (IA-2014-06).pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2021: 0.74 segundos
# Tempo para processar 19957-011657-2019-40 (SP-2020-00035).pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2021: 0.39 segundos
# Tempo para processar 19957-011693-2017-41 (SP-2018-00420).pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\
pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2023: 0.59 segundos
# Tempo para processar 19957-015734-2022-36.pdf da pasta T:/T0mas/Faculdade/Bolsa PUB/Data\2023: 0.34 segundos
# Tempo total de execução: 816.84 segundos
#                         ID                                    Data  \
# 0               IA-1995-21     Rio de Janeiro, 08 de junho de 2000
# 1               IA-1996-10  Rio de Janeiro, 09 de novembro de 2000
# 2               IA-1997-12                                     NaN
# 3               IA-1998-01    Rio de Janeiro, 17 de agosto de 2000
# 4               IA-1998-05  Rio de Janeiro, 16 de novembro de 2000
# ...                    ...                                     ...
# 1266  19957-011361-2018-48          Data do julgamento: 27/06/2023
# 1267  19957-011669-2017-11          Data do julgamento: 19/09/2023
# 1268  19957-012126-2022-70          Data do julgamento: 06/06/2023
# 1269  19957-012414-2022-24          Data do julgamento: 11/07/2023
# 1270  19957-015734-2022-36          Data do julgamento: 22/08/2023
#
#                                                Acusados  \
# 0     [Alfredo Egydio Setúbal, Banco do Brasil S/A, ...
# 1     [Alfredo Egydio Setúbal, Banco Itaú S/A., Edua...
# 2     [Antônio Bosco da Costa, Antonio Carlos Martin...
# 3     [Bittencourt S/A CTVC Carlos Guilherme Frederi...
# 4     [DC Corretora de Câmbio, Títulos e Valores Mob...
# ...                                                 ...
# 1266  [YDUQS Participações S.A., Marcos de Oliveira ...
# 1267  [Luis Fernando Costa Estima, Estimapar Investi...
# 1268  [Ingomar Mueller, Bruno Lippel, Multiplus Asse...
# 1269  [José Almiro Bihl, Dirce Simioni Bihl, Aline C...
# 1270                 [Paulo Navarro de Oliveira Junior]
#
#                                                 Assunto  \
# 0     Práticas não-equitativas em operações day-trad...
# 1     Práticas não-equitativas no mercado de valores...
# 2     Emissão pública de debêntures realizada pela E...
# 3     Irregularidades na recepção, preenchimento, di...
# 4     Operações fraudulentas no mercado futuro de ín...
# ...                                                 ...
# 1266  Apurar eventual responsabilidade de companhia ...
# 1267  Apuração de eventuais irregularidades relacion...
# 1268  Apurar supostas práticas de administração irre...
# 1269  Apurar eventual responsabilidade de administra...
# 1270  Exercício irregular de atividade de administra...
#
#                                                 Decisão
# 0     Vistos, relatados e discutidos os autos, o Col...
# 1     Vistos, relatados e discutidos os autos, o Col...
# 2                                                   NaN
# 3     Vistos, relatados e discutidos os autos, o Col...
# 4     Vistos, relatados e discutidos os autos, o Col...
# ...                                                 ...
# 1266  Vistos, relatados e discutidos os autos, o Col...
# 1267  Vistos, relatados e discutidos os autos, o Col...
# 1268  Vistos, relatados e discutidos os autos, o Col...
# 1269  Vistos, relatados e discutidos os autos, o Col...
# 1270  Vistos, relatados e discutidos os autos, o Col...
#
# [1271 rows x 5 columns]

# %%
nan_count = df.isna().sum()
print(nan_count)
# Out:
# ID            0
# Data        201
# Acusados      0
# Assunto      98
# Decisão     220
# dtype: int64

# %%
empty_lists_count = df['Acusados'].apply(lambda x: x == []).sum()
print(empty_lists_count)
# Out:
# 38

# %%
rows_with_nan = df.isna().any(axis=1).sum()
print(rows_with_nan)
# Out:
# 282

# %%
df.to_csv('T:/T0mas/Faculdade/Bolsa PUB/Github CVM/corporate-fraud-in-brazil/Bases de dados/Base de Dados Final.csv', index=False)
