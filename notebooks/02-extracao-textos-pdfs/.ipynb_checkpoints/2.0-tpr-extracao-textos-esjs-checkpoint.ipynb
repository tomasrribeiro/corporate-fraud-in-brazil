# %% [markdown]
# # Extração dos textos - ESJs

# %% [markdown]
# O objetivo deste código é extrair o texto do PDF de todos os processos disponíveis. Como resultado, teremos uma base de dados com duas colunas: ID do processo e texto, que sera uma entrada string que contém todo o texto dos processos.

# %% [markdown]
# ## Importando pacotes e definindo diretório

# %%
# !pip install pdfplumber
# Out:
# Requirement already satisfied: pdfplumber in c:\anaconda\lib\site-packages (0.11.7)
# Requirement already satisfied: pdfminer.six==20250506 in c:\anaconda\lib\site-packages (from pdfplumber) (20250506)
# Requirement already satisfied: Pillow>=9.1 in c:\anaconda\lib\site-packages (from pdfplumber) (11.1.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in c:\anaconda\lib\site-packages (from pdfplumber) (4.30.1)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\anaconda\lib\site-packages (from pdfminer.six==20250506->pdfplumber) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in c:\anaconda\lib\site-packages (from pdfminer.six==20250506->pdfplumber) (44.0.1)
# Requirement already satisfied: cffi>=1.12 in c:\anaconda\lib\site-packages (from cryptography>=36.0.0->pdfminer.six==20250506->pdfplumber) (1.17.1)
# Requirement already satisfied: pycparser in c:\anaconda\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20250506->pdfplumber) (2.21)

# %%
import os
import pandas as pd
import re
import random
import shutil
import pdfplumber
import numpy as np
import time
from pdf2image import convert_from_path
from PIL import Image
import pytesseract
from fpdf import FPDF

# %% [markdown]
# Agora, vamos definir o caminho da pasta que tem os arquivos:

# %%
pasta_principal = "D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs"

# %% [markdown]
# ## Extração dos textos e criação do df

# %%
def extrair_texto_pdf(caminho_pdf):
    # Definimos o caminho para o pdf
    nome_arquivo = os.path.basename(caminho_pdf)

    # Padrões para extrair os arquivos, análogos aos dos outros códigos.
    pattern_processo_nome_arquivo = r"(?:\d{5}-\d{6}-\d{4}-\d{2}|IA-\d{4}-\d{2}|RJ-\d{4}-\d{5}|SP-\d{4}-\d{5})"
    match_processo_nome_arquivo = re.search(pattern_processo_nome_arquivo, nome_arquivo)
    numero_processo = match_processo_nome_arquivo.group(0) if match_processo_nome_arquivo else np.nan

    # Extração do texto:
    with pdfplumber.open(caminho_pdf) as pdf: #Abrir o PDF
        text = "\n".join(page.extract_text() or "" for page in pdf.pages) #Extrair o texto

    return numero_processo, text #Retornamos o número do processo e o texto.

# %% [markdown]
# Adicionando os escaneados:

# %%
def extrair_texto_pdf(caminho_pdf, min_chars=2000):
    """
    Extrai texto de um PDF. Se o texto for vazio ou muito curto, tenta OCR.
    Retorna (numero_processo, texto, escaneado)
    """
    # 1️⃣ Número do processo a partir do nome do arquivo
    nome_arquivo = os.path.basename(caminho_pdf)
    pattern_processo_nome_arquivo = r"(?:\d{5}-\d{6}-\d{4}-\d{2}|IA-\d{4}-\d{2}|RJ-\d{4}-\d{5}|SP-\d{4}-\d{5})"
    match_processo_nome_arquivo = re.search(pattern_processo_nome_arquivo, nome_arquivo)
    numero_processo = match_processo_nome_arquivo.group(0) if match_processo_nome_arquivo else np.nan
    
    # Inicializar a variável escaneado
    escaneado = False
    
    # 2️⃣ Tenta extrair texto normalmente
    with pdfplumber.open(caminho_pdf) as pdf:
        texto = "\n".join(page.extract_text() or "" for page in pdf.pages)
    
    # 3️⃣ Se texto muito curto ou vazio, tentar OCR
    if len(texto.strip()) < min_chars:
        print(f"⚠️ Texto curto para {nome_arquivo}, tentando OCR...")
        try:
            imagens = convert_from_path(caminho_pdf)
            texto_ocr = "\n".join(pytesseract.image_to_string(img, lang='por') for img in imagens)
            
            # Se OCR encontrou mais texto, substitui
            if len(texto_ocr.strip()) > len(texto.strip()):
                texto = texto_ocr
                escaneado = True
            # Se não encontrou mais texto, mantém escaneado = False
                
        except Exception as e:
            print(f"❌ Falha no OCR para {nome_arquivo}: {e}")
            # escaneado permanece False em caso de erro
    
    return numero_processo, texto, escaneado

# %%
# Lista para acumular os dados
dados = []
# Iniciar o timer total
start_time = time.time()

# Loop pelas subpastas de anos (2000 a 2023)
for ano in range(2000, 2024):
    subpasta = os.path.join(pasta_principal, str(ano))  # Caminho para a subpasta do ano
    
    if os.path.exists(subpasta):  # Verifica se a subpasta existe
        for arquivo in os.listdir(subpasta):  # Lista todos os arquivos na subpasta
            if arquivo.endswith('.pdf'):
                caminho_pdf = os.path.join(subpasta, arquivo)
                # Timer para cada iteração
                iter_start = time.time()
                try:
                    # Extrair informações do PDF (agora retorna 3 valores)
                    numero_processo, texto, escaneado = extrair_texto_pdf(caminho_pdf)
                    
                    # Adicionar dados à lista
                    dados.append({
                        "ID": numero_processo,
                        "Texto": texto,
                        "Escaneado": escaneado
                    })
                except Exception as e:
                    print(f"Erro ao processar {arquivo} na pasta {subpasta}: {e}")
                    continue
                
                # Timer de cada iteração
                iter_end = time.time()
                iter_time = iter_end - iter_start
                print(f"Tempo para processar {arquivo} da pasta {subpasta}: {iter_time:.2f} segundos")

# Criar o DataFrame com todos os dados
df = pd.DataFrame(dados)

# Calcular o tempo total
end_time = time.time()
execution_time = end_time - start_time
print(f"Tempo total de execução: {execution_time:.2f} segundos")

# Exibir o DataFrame com todos os resultados
print(f"Total de PDFs processados: {len(df)}")
print(f"PDFs que precisaram de OCR: {df['Escaneado'].sum()}")
df
# Out:
# Tempo para processar IA-1995-21.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2000: 10.88 segundos
# Tempo para processar IA-1996-10.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2000: 11.22 segundos
# Tempo para processar IA-1997-12.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2000: 19.58 segundos
# Tempo para processar IA-1998-01.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2000: 6.27 segundos
# Tempo para processar IA-1998-05_B.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2000: 3.27 segundos
# Tempo para processar IA-1998-13.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2000: 3.58 segundos
# Tempo para processar IA-1998-17.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2000: 3.45 segundos
# Tempo para processar IA-1998-33.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2000: 4.63 segundos
# Tempo para processar IA-1998-35.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2000: 5.00 segundos
# Tempo para processar IA-1998-36_A.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2000: 3.58 segundos
# Tempo para processar IA-1999-05.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2000: 5.62 segundos
# Tempo para processar IA-1999-08.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2000: 6.06 segundos
# Tempo para processar IA-1999-09.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2000: 4.70 segundos
# Tempo para processar IA-1999-10.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2000: 4.17 segundos
# Tempo para processar IA-1999-14.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2000: 2.41 segundos
# Tempo para processar IA-1999-16.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2000: 3.50 segundos
# Tempo para processar IA-1999-19.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2000: 1.59 segundos
# Tempo para processar IA-1999-23.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2000: 5.54 segundos
# Tempo para processar IA-1999-25.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2000: 2.40 segundos
# Tempo para processar IA-1997-11.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2001: 20.15 segundos
# Tempo para processar IA-1997-15.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2001: 18.29 segundos
# Tempo para processar IA-1998-08.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2001: 6.67 segundos
# Tempo para processar IA-1998-19.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2001: 3.74 segundos
# Tempo para processar IA-1998-20.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2001: 2.71 segundos
# Tempo para processar IA-1998-24.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2001: 9.06 segundos
# Tempo para processar IA-1998-25.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2001: 7.47 segundos
# Tempo para processar IA-1998-29.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2001: 8.23 segundos
# Tempo para processar IA-1998-30.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2001: 2.88 segundos
# Tempo para processar IA-1998-36_B.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2001: 1.31 segundos
# Tempo para processar IA-1998-38.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2001: 5.75 segundos
# Tempo para processar IA-1998-39.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2001: 3.19 segundos
# Tempo para processar IA-1999-01.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2001: 15.02 segundos
# Tempo para processar IA-1999-02.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2001: 11.23 segundos
# Tempo para processar IA-1999-03.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2001: 4.73 segundos
# Tempo para processar IA-1999-13.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2001: 3.84 segundos
# Tempo para processar IA-1999-15.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2001: 5.10 segundos
# Tempo para processar IA-1999-17.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2001: 2.19 segundos
# Tempo para processar IA-1999-18.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2001: 8.57 segundos
# Tempo para processar IA-1999-22.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2001: 4.53 segundos
# Tempo para processar IA-1999-26.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2001: 2.89 segundos
# Tempo para processar IA-1999-29.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2001: 4.23 segundos
# Tempo para processar IA-1999-30.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2001: 2.41 segundos
# Tempo para processar IA-1999-33.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2001: 5.73 segundos
# Tempo para processar IA-1999-34.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2001: 7.41 segundos
# Tempo para processar IA-2000-02.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2001: 4.86 segundos
# Tempo para processar IA-2000-03.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2001: 4.98 segundos
# Tempo para processar IA-2000-07.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2001: 3.93 segundos
# Tempo para processar IA-2000-20.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2001: 2.53 segundos
# Tempo para processar IA-2000-22.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2001: 2.44 segundos
# Tempo para processar IA-2000-32.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2001: 3.11 segundos
# Tempo para processar RJ-2000-05907.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2001: 0.93 segundos
# Tempo para processar RJ-2001-01950.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2001: 2.21 segundos
# Tempo para processar RJ-2001-04977.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2001: 13.79 segundos
# Tempo para processar RJ-2001-06094.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2001: 4.05 segundos
# Tempo para processar SP-2001-00001.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2001: 1.52 segundos
# Tempo para processar IA-1994-06.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2002: 7.44 segundos
# Tempo para processar IA-1996-12.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2002: 3.37 segundos
# Tempo para processar IA-1999-04.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2002: 18.63 segundos
# Tempo para processar IA-1999-06.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2002: 2.90 segundos
# Tempo para processar IA-1999-20.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2002: 4.30 segundos
# Tempo para processar IA-2000-06.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2002: 5.72 segundos
# Tempo para processar IA-2000-08.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2002: 2.48 segundos
# Tempo para processar IA-2000-12.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2002: 4.83 segundos
# Tempo para processar IA-2000-13.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2002: 3.82 segundos
# Tempo para processar IA-2000-16.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2002: 6.41 segundos
# Tempo para processar IA-2000-26.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2002: 3.73 segundos
# Tempo para processar IA-2000-28.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2002: 6.55 segundos
# Tempo para processar IA-2000-33.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2002: 7.10 segundos
# Tempo para processar IA-2001-01.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2002: 3.93 segundos
# Tempo para processar RJ-2000-04546.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2002: 4.16 segundos
# Tempo para processar RJ-2000-06498.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2002: 6.95 segundos
# Tempo para processar RJ-2001-00554.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2002: 3.95 segundos
# Tempo para processar RJ-2001-03809.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2002: 1.51 segundos
# Tempo para processar RJ-2001-04187.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2002: 3.38 segundos
# Tempo para processar RJ-2001-06835.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2002: 1.50 segundos
# Tempo para processar RJ-2001-07661.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2002: 1.25 segundos
# Tempo para processar RJ-2001-07686.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2002: 3.12 segundos
# Tempo para processar RJ-2001-08023.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2002: 3.02 segundos
# Tempo para processar RJ-2001-08045.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2002: 1.40 segundos
# Tempo para processar RJ-2001-08280.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2002: 3.74 segundos
# Tempo para processar RJ-2001-08388.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2002: 1.12 segundos
# Tempo para processar RJ-2002-01153.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2002: 13.03 segundos
# Tempo para processar SP-2001-00003.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2002: 9.93 segundos
# Tempo para processar SP-2001-00140.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2002: 2.19 segundos
# Tempo para processar SP-2001-00724.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2002: 5.01 segundos
# Tempo para processar IA-1998-11.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2003: 2.90 segundos
# Tempo para processar IA-1999-28.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2003: 6.10 segundos
# Tempo para processar IA-1999-35.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2003: 15.93 segundos
# Tempo para processar IA-2000-31.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2003: 22.06 segundos
# Tempo para processar IA-2000-38.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2003: 8.70 segundos
# Tempo para processar IA-2001-17.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2003: 8.23 segundos
# Tempo para processar IA-2002-04.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2003: 6.76 segundos
# Tempo para processar RJ-2000-06479.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2003: 6.59 segundos
# Tempo para processar RJ-2001-01826.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2003: 5.90 segundos
# Tempo para processar RJ-2001-04355.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2003: 2.47 segundos
# Tempo para processar RJ-2001-06226.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2003: 1.97 segundos
# Tempo para processar RJ-2001-08385.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2003: 3.31 segundos
# Tempo para processar RJ-2001-08739.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2003: 5.55 segundos
# Tempo para processar RJ-2001-09701.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2003: 3.48 segundos
# Tempo para processar RJ-2001-09999.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2003: 10.19 segundos
# Tempo para processar RJ-2001-12173.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2003: 3.15 segundos
# Tempo para processar RJ-2002-00444.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2003: 5.11 segundos
# Tempo para processar RJ-2002-01173.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2003: 10.97 segundos
# Tempo para processar RJ-2002-02405.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2003: 20.42 segundos
# Tempo para processar RJ-2002-02937.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2003: 3.60 segundos
# Tempo para processar RJ-2002-03535.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2003: 6.69 segundos
# Tempo para processar RJ-2002-04589.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2003: 2.69 segundos
# Tempo para processar RJ-2002-05015.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2003: 2.10 segundos
# Tempo para processar RJ-2002-05018.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2003: 1.36 segundos
# Tempo para processar RJ-2002-05101.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2003: 2.07 segundos
# Tempo para processar RJ-2002-06765.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2003: 1.92 segundos
# Tempo para processar RJ-2002-06982.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2003: 1.70 segundos
# Tempo para processar RJ-2003-00435.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2003: 5.03 segundos
# Tempo para processar RJ-2003-04953.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2003: 2.21 segundos
# Tempo para processar RJ-2003-05486.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2003: 2.52 segundos
# Tempo para processar SP-2001-00307.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2003: 2.73 segundos
# Tempo para processar SP-2001-00386.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2003: 3.07 segundos
# Tempo para processar SP-2001-00395.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2003: 2.92 segundos
# Tempo para processar SP-2001-00725.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2003: 4.48 segundos
# Tempo para processar SP-2002-00047.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2003: 4.17 segundos
# Tempo para processar SP-2002-00048.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2003: 4.24 segundos
# Tempo para processar SP-2002-00098.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2003: 6.22 segundos
# Tempo para processar SP-2002-00257.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2003: 3.99 segundos
# Tempo para processar SP-2002-00397.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2003: 11.29 segundos
# Tempo para processar SP-2002-00564.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2003: 5.76 segundos
# Tempo para processar SP-2003-00148.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2003: 6.52 segundos
# Tempo para processar IA-1994-22.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 6.40 segundos
# Tempo para processar IA-1996-03.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 22.37 segundos
# Tempo para processar IA-1997-03.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 20.16 segundos
# Tempo para processar IA-1998-12.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 10.33 segundos
# Tempo para processar IA-1998-32.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 8.67 segundos
# Tempo para processar IA-1998-34.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 3.48 segundos
# Tempo para processar IA-1999-21.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 5.15 segundos
# Tempo para processar IA-1999-27.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 5.01 segundos
# Tempo para processar IA-2000-05.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 26.76 segundos
# Tempo para processar IA-2000-09.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 2.01 segundos
# Tempo para processar IA-2000-10.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 9.22 segundos
# Tempo para processar IA-2000-14.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 6.36 segundos
# Tempo para processar IA-2000-17.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 4.52 segundos
# Tempo para processar IA-2000-21.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 1.64 segundos
# Tempo para processar IA-2000-25.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 2.58 segundos
# Tempo para processar IA-2000-27.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 1.47 segundos
# Tempo para processar IA-2000-34.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 9.14 segundos
# Tempo para processar IA-2000-37.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 7.48 segundos
# Tempo para processar IA-2001-05.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 8.40 segundos
# Tempo para processar IA-2001-06.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 8.89 segundos
# Tempo para processar IA-2001-08.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 10.38 segundos
# Tempo para processar IA-2001-18.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 18.46 segundos
# Tempo para processar IA-2002-03.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 4.96 segundos
# Tempo para processar IA-2002-05.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 14.33 segundos
# Tempo para processar IA-2002-07.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 15.90 segundos
# Tempo para processar IA-2002-10.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 4.32 segundos
# Tempo para processar RJ-2001-04635.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 9.45 segundos
# Tempo para processar RJ-2001-07557.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 3.60 segundos
# Tempo para processar RJ-2001-07749.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 4.67 segundos
# Tempo para processar RJ-2001-08029.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 6.35 segundos
# Tempo para processar RJ-2001-08473.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 10.42 segundos
# Tempo para processar RJ-2001-09686.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 9.94 segundos
# Tempo para processar RJ-2002-00445.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 2.90 segundos
# Tempo para processar RJ-2002-01846.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 7.37 segundos
# Tempo para processar RJ-2002-03087.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 2.25 segundos
# Tempo para processar RJ-2002-04936.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 5.05 segundos
# Tempo para processar RJ-2002-05113.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 4.76 segundos
# Tempo para processar RJ-2002-06738.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 13.54 segundos
# Tempo para processar RJ-2002-07539.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 2.84 segundos
# Tempo para processar RJ-2002-07635.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 8.50 segundos
# Tempo para processar RJ-2002-08428.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 7.76 segundos
# Tempo para processar RJ-2003-05753.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 3.76 segundos
# Tempo para processar RJ-2003-08172.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 7.25 segundos
# Tempo para processar RJ-2003-12818.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 4.86 segundos
# Tempo para processar RJ-2003-13210.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 1.89 segundos
# Tempo para processar RJ-2004-01844.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 2.04 segundos
# Tempo para processar RJ-2004-03456.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 4.60 segundos
# Tempo para processar RJ-2004-05131.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 2.38 segundos
# Tempo para processar SP-2001-00034.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 9.62 segundos
# Tempo para processar SP-2001-00236.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 13.32 segundos
# Tempo para processar SP-2001-00240.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 6.61 segundos
# Tempo para processar SP-2001-00373.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 2.10 segundos
# Tempo para processar SP-2001-00465.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 6.50 segundos
# Tempo para processar SP-2002-00197.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 17.97 segundos
# Tempo para processar SP-2002-00462.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 1.52 segundos
# Tempo para processar SP-2002-00487.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 1.84 segundos
# Tempo para processar SP-2003-00042.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 3.23 segundos
# Tempo para processar SP-2003-00100.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 1.18 segundos
# Tempo para processar SP-2003-00288.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 3.63 segundos
# Tempo para processar SP-2003-00446.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 4.12 segundos
# Tempo para processar SP-2004-00113.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 4.85 segundos
# Tempo para processar SP-2004-00123.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2004: 4.06 segundos
# Tempo para processar IA-1995-06.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 6.01 segundos
# Tempo para processar IA-1996-11.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 12.69 segundos
# Tempo para processar IA-1997-17_A.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 8.28 segundos
# Tempo para processar IA-1997-17_B.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 7.17 segundos
# Tempo para processar IA-1998-31.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 5.38 segundos
# Tempo para processar IA-2000-04.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 21.33 segundos
# Tempo para processar IA-2000-24.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 12.57 segundos
# Tempo para processar IA-2000-35.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 23.53 segundos
# Tempo para processar IA-2000-39.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 8.06 segundos
# Tempo para processar IA-2001-04.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 5.42 segundos
# Tempo para processar IA-2001-07.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 6.32 segundos
# Tempo para processar IA-2001-14.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 13.66 segundos
# Tempo para processar IA-2001-16.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 13.01 segundos
# Tempo para processar IA-2002-01.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 7.73 segundos
# Tempo para processar IA-2002-06.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 6.37 segundos
# Tempo para processar IA-2002-17.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 8.40 segundos
# Tempo para processar IA-2003-04.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 7.35 segundos
# Tempo para processar IA-2003-06.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 8.31 segundos
# Tempo para processar IA-2003-10.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 11.04 segundos
# Tempo para processar IA-2003-13.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 5.85 segundos
# Tempo para processar IA-2003-18.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 11.73 segundos
# Tempo para processar IA-2003-24.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 12.74 segundos
# Tempo para processar IA-2003-27.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 8.91 segundos
# Tempo para processar IA-2004-01.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 4.57 segundos
# Tempo para processar IA-2004-02.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 12.86 segundos
# Tempo para processar IA-2004-11.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 6.46 segundos
# Tempo para processar RJ-2001-04474.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 5.18 segundos
# Tempo para processar RJ-2001-08028.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 8.76 segundos
# Tempo para processar RJ-2001-08363.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 11.23 segundos
# Tempo para processar RJ-2001-11949.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 13.45 segundos
# Tempo para processar RJ-2002-01415.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 4.91 segundos
# Tempo para processar RJ-2002-01822.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 3.22 segundos
# Tempo para processar RJ-2002-01823.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 5.47 segundos
# Tempo para processar RJ-2002-02047.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 7.17 segundos
# Tempo para processar RJ-2002-04985.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 3.91 segundos
# Tempo para processar RJ-2002-06413.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 1.97 segundos
# Tempo para processar RJ-2003-00823.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 9.45 segundos
# Tempo para processar RJ-2003-01631.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 5.34 segundos
# Tempo para processar RJ-2003-05058.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 24.91 segundos
# Tempo para processar RJ-2003-05509.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 8.93 segundos
# Tempo para processar RJ-2003-05596.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 10.37 segundos
# Tempo para processar RJ-2003-05627.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 1.15 segundos
# Tempo para processar RJ-2003-05849.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 10.58 segundos
# Tempo para processar RJ-2003-06098.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 7.20 segundos
# Tempo para processar RJ-2003-06894.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 7.40 segundos
# Tempo para processar RJ-2003-07642.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 7.77 segundos
# Tempo para processar RJ-2003-07697.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 9.86 segundos
# Tempo para processar RJ-2003-11503.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 3.30 segundos
# Tempo para processar RJ-2003-12233.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 7.93 segundos
# Tempo para processar RJ-2003-12312.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 7.86 segundos
# Tempo para processar RJ-2003-12911.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 2.57 segundos
# Tempo para processar RJ-2004-02132.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 1.73 segundos
# Tempo para processar RJ-2004-03169.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 1.55 segundos
# Tempo para processar RJ-2004-04627.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 1.64 segundos
# Tempo para processar RJ-2004-05238.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 6.53 segundos
# Tempo para processar RJ-2004-06238.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 3.17 segundos
# Tempo para processar RJ-2004-07001.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 7.12 segundos
# Tempo para processar RJ-2005-00033.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 10.41 segundos
# Tempo para processar RJ-2005-01860.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 3.09 segundos
# ⚠️ Texto curto para RJ-2005-01952.pdf, tentando OCR...
# ❌ Falha no OCR para RJ-2005-01952.pdf: Unable to get page count. Is poppler installed and in PATH?
# Tempo para processar RJ-2005-01952.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 0.22 segundos
# Tempo para processar RJ-2005-02793.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 3.48 segundos
# Tempo para processar RJ-2005-02815.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 4.53 segundos
# Tempo para processar RJ-2005-03106.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 1.33 segundos
# Tempo para processar RJ-2005-03646.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 2.28 segundos
# Tempo para processar RJ-2005-03711.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 1.31 segundos
# Tempo para processar RJ-2005-03750.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 2.40 segundos
# Tempo para processar RJ-2005-04215.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 2.61 segundos
# Tempo para processar RJ-2005-05204.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 2.33 segundos
# Tempo para processar SP-2001-00799.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 5.58 segundos
# Tempo para processar SP-2002-00049.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 4.56 segundos
# Tempo para processar SP-2002-00493.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 6.54 segundos
# Tempo para processar SP-2003-00070.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 5.90 segundos
# Tempo para processar SP-2003-00313.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 1.05 segundos
# Tempo para processar SP-2003-00324.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 4.67 segundos
# Tempo para processar SP-2003-00444.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 3.83 segundos
# Tempo para processar SP-2003-00445.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 7.60 segundos
# Tempo para processar SP-2003-00466.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 3.40 segundos
# ⚠️ Texto curto para SP-2004-00104.pdf, tentando OCR...
# ❌ Falha no OCR para SP-2004-00104.pdf: Unable to get page count. Is poppler installed and in PATH?
# Tempo para processar SP-2004-00104.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 0.22 segundos
# Tempo para processar SP-2004-00154.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 3.05 segundos
# Tempo para processar SP-2005-00158.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2005: 1.74 segundos
# Tempo para processar IA-1993-09.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2006: 5.27 segundos
# Tempo para processar IA-1995-03.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2006: 7.84 segundos
# Tempo para processar IA-1996-22.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2006: 6.28 segundos
# Tempo para processar IA-1997-09.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2006: 46.07 segundos
# Tempo para processar IA-1999-32.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2006: 16.11 segundos
# Tempo para processar IA-2000-30.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2006: 7.05 segundos
# Tempo para processar IA-2001-12.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2006: 7.84 segundos
# Tempo para processar IA-2001-13.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2006: 7.38 segundos
# Tempo para processar IA-2002-09.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2006: 5.84 segundos
# Tempo para processar IA-2002-13.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2006: 4.77 segundos
# Tempo para processar IA-2002-16.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2006: 7.27 segundos
# Tempo para processar IA-2003-03.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2006: 7.74 segundos
# Tempo para processar IA-2003-09.pdf da pasta D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/raw/pdfs/esjs\2006: 12.25 segundos
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 18
#      15 iter_start = time.time()
#      16 try:
#      17     # Extrair informações do PDF (agora retorna 3 valores)
# ---> 18     numero_processo, texto, escaneado = extrair_texto_pdf(caminho_pdf)
#      20     # Adicionar dados à lista
#      21     dados.append({
#      22         "ID": numero_processo,
#      23         "Texto": texto,
#      24         "Escaneado": escaneado
#      25     })
#
# Cell In[20], line 17, in extrair_texto_pdf(caminho_pdf, min_chars)
#      15 # 2️⃣ Tenta extrair texto normalmente
#      16 with pdfplumber.open(caminho_pdf) as pdf:
# ---> 17     texto = "\n".join(page.extract_text() or "" for page in pdf.pages)
#      19 # 3️⃣ Se texto muito curto ou vazio, tentar OCR
#      20 if len(texto.strip()) < min_chars:
#
# Cell In[20], line 17, in <genexpr>(.0)
#      15 # 2️⃣ Tenta extrair texto normalmente
#      16 with pdfplumber.open(caminho_pdf) as pdf:
# ---> 17     texto = "\n".join(page.extract_text() or "" for page in pdf.pages)
#      19 # 3️⃣ Se texto muito curto ou vazio, tentar OCR
#      20 if len(texto.strip()) < min_chars:
#
# File C:\Anaconda\Lib\site-packages\pdfplumber\page.py:530, in Page.extract_text(self, **kwargs)
#     529 def extract_text(self, **kwargs: Any) -> str:
# --> 530     return self.get_textmap(**tuplify_list_kwargs(kwargs)).as_string
#
# File C:\Anaconda\Lib\site-packages\pdfplumber\page.py:507, in Page._get_textmap(self, **kwargs)
#     505     defaults.update({"layout_height": self.height})
#     506 full_kwargs: Dict[str, Any] = {**defaults, **kwargs}
# --> 507 return utils.chars_to_textmap(self.chars, **full_kwargs)
#
# File C:\Anaconda\Lib\site-packages\pdfplumber\container.py:52, in Container.chars(self)
#      50 @property
#      51 def chars(self) -> T_obj_list:
# ---> 52     return self.objects.get("char", [])
#
# File C:\Anaconda\Lib\site-packages\pdfplumber\page.py:346, in Page.objects(self)
#     344 if hasattr(self, "_objects"):
#     345     return self._objects
# --> 346 self._objects: Dict[str, T_obj_list] = self.parse_objects()
#     347 return self._objects
#
# File C:\Anaconda\Lib\site-packages\pdfplumber\page.py:443, in Page.parse_objects(self)
#     441 def parse_objects(self) -> Dict[str, T_obj_list]:
#     442     objects: Dict[str, T_obj_list] = {}
# --> 443     for obj in self.iter_layout_objects(self.layout._objs):
#     444         kind = obj["object_type"]
#     445         if kind in ["anno"]:
#
# File C:\Anaconda\Lib\site-packages\pdfplumber\page.py:266, in Page.layout(self)
#     264 interpreter = PDFPageInterpreter(self.pdf.rsrcmgr, device)
#     265 try:
# --> 266     interpreter.process_page(self.page_obj)
#     267 except Exception as e:
#     268     raise PdfminerException(e)
#
# File C:\Anaconda\Lib\site-packages\pdfminer\pdfinterp.py:1210, in PDFPageInterpreter.process_page(self, page)
#    1208     ctm = (1, 0, 0, 1, -x0, -y0)
#    1209 self.device.begin_page(page, ctm)
# -> 1210 self.render_contents(page.resources, page.contents, ctm=ctm)
#    1211 self.device.end_page(page)
#
# File C:\Anaconda\Lib\site-packages\pdfminer\pdfinterp.py:1231, in PDFPageInterpreter.render_contents(self, resources, streams, ctm)
#    1229 self.init_resources(resources)
#    1230 self.init_state(ctm)
# -> 1231 self.execute(list_value(streams))
#
# File C:\Anaconda\Lib\site-packages\pdfminer\pdfinterp.py:1241, in PDFPageInterpreter.execute(self, streams)
#    1239 while True:
#    1240     try:
# -> 1241         (_, obj) = parser.nextobject()
#    1242     except PSEOF:
#    1243         break
#
# File C:\Anaconda\Lib\site-packages\pdfminer\psparser.py:596, in PSStackParser.nextobject(self)
#     588 """Yields a list of objects.
#     589
#     590 Arrays and dictionaries are represented as Python lists and
#    (...)
#     593 :return: keywords, literals, strings, numbers, arrays and dictionaries.
#     594 """
#     595 while not self.results:
# --> 596     (pos, token) = self.nexttoken()
#     597     if isinstance(token, (int, float, bool, str, bytes, PSLiteral)):
#     598         # normal token
#     599         self.push((pos, token))
#
# File C:\Anaconda\Lib\site-packages\pdfminer\psparser.py:507, in PSBaseParser.nexttoken(self)
#     504 if self.eof:
#     505     # It's not really unexpected, come on now...
#     506     raise PSEOF("Unexpected EOF")
# --> 507 while not self._tokens:
#     508     try:
#     509         self.fillbuf()
#
# KeyboardInterrupt:

# %%
df.to_csv("D:/Backup Tomas/T0mas/Faculdade/IC/Geral/Github CVM/corporate-fraud-in-brazil/data/processed/textos_dos_processos/textos_esjs.csv", index=False)
